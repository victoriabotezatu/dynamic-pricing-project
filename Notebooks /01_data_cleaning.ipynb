# %% [markdown]
# # Data Cleaning Notebook
#
# The notebook contains the data cleaning process for the dynamic pricing ride-sharing dataset

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
file_path = "../Data/Raw/dynamic_pricing(in).csv"

if os.path.exists(file_path):
    print("File found.")
else:
    print("File not found.")
# Out:
# File found.

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Number_of_Riders         1000 non-null   int64
#  1   Number_of_Drivers        1000 non-null   int64
#  2   Location_Category        1000 non-null   object
#  3   Customer_Loyalty_Status  1000 non-null   object
#  4   Number_of_Past_Rides     1000 non-null   int64
#  5   Average_Ratings          1000 non-null   float64
#  6   Time_of_Booking          1000 non-null   object
#  7   Vehicle_Type             1000 non-null   object
#  8   Expected_Ride_Duration   1000 non-null   int64
#  9   Historical_Cost_of_Ride  1000 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#        Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# count       1000.000000        1000.000000           1000.000000
# mean          60.372000          27.076000             50.031000
# std           23.701506          19.068346             29.313774
# min           20.000000           5.000000              0.000000
# 25%           40.000000          11.000000             25.000000
# 50%           60.000000          22.000000             51.000000
# 75%           81.000000          38.000000             75.000000
# max          100.000000          89.000000            100.000000
#
#        Average_Ratings  Expected_Ride_Duration  Historical_Cost_of_Ride
# count      1000.000000              1000.00000              1000.000000
# mean          4.257220                99.58800               372.502623
# std           0.435781                49.16545               187.158756
# min           3.500000                10.00000                25.993449
# ...

# %% [markdown]
# ## Column Names
# Checking if the columns have clear names and do not contain extra spaces

# %%
df.columns
# Out:
# Index(['Number_of_Riders', 'Number_of_Drivers', 'Location_Category',
#        'Customer_Loyalty_Status', 'Number_of_Past_Rides', 'Average_Ratings',
#        'Time_of_Booking', 'Vehicle_Type', 'Expected_Ride_Duration',
#        'Historical_Cost_of_Ride'],
#       dtype='object')

# %%
df_columns = df.columns.str.strip()
df_columns
# Out:
# Index(['Number_of_Riders', 'Number_of_Drivers', 'Location_Category',
#        'Customer_Loyalty_Status', 'Number_of_Past_Rides', 'Average_Ratings',
#        'Time_of_Booking', 'Vehicle_Type', 'Expected_Ride_Duration',
#        'Historical_Cost_of_Ride'],
#       dtype='object')

# %% [markdown]
# ## Missing Values
# Checking if the dataset contains missing values

# %%
df.isnull().sum()
# Out:
# Number_of_Riders           0
# Number_of_Drivers          0
# Location_Category          0
# Customer_Loyalty_Status    0
# Number_of_Past_Rides       0
# Average_Ratings            0
# Time_of_Booking            0
# Vehicle_Type               0
# Expected_Ride_Duration     0
# Historical_Cost_of_Ride    0
# dtype: int64

# %% [markdown]
# No missing values were found in the dataset. No replacement or removal of missing data was necessary

# %% [markdown]
# ## Duplicate Records
# Checking if the dataset contains duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The duplicate check returned 0. This means that no dupliacte rows are in the dataset. Therefore, no rows have to be removed

# %% [markdown]
# ## Categorical Variables
#
# Checking the unique values in the categorical columns to identify possible spelling mistakes or inconsistent categories

# %%
df["Location_Category"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
df["Customer_Loyalty_Status"].unique()
# Out:
# array(['Silver', 'Regular', 'Gold'], dtype=object)

# %%
df["Time_of_Booking"].unique()
# Out:
# array(['Night', 'Evening', 'Afternoon', 'Morning'], dtype=object)

# %%
df["Vehicle_Type"].unique()
# Out:
# array(['Premium', 'Economy'], dtype=object)

# %% [markdown]
# ## Invalid Values
#
# Checking if the numerical columns contain impossible values, such as negative numbers or ratings outside the expected range

# %%
df["Number_of_Riders"].min()
# Out:
# 20

# %%
df["Number_of_Drivers"].min()
# Out:
# 5

# %%
df["Average_Ratings"].min()
# Out:
# 3.5

# %%
df["Average_Ratings"].max()
# Out:
# 5.0

# %%
df["Expected_Ride_Duration"].min()
# Out:
# 10

# %%
df["Historical_Cost_of_Ride"].min()
# Out:
# 25.993449448411635

# %% [markdown]
# The numerical columns do not show impossible values. Rider count, driver count, ride duration, and ride cost are all positive.
#
# For `Average_Ratings`, the values range from 3.5 to 5.0. Since this fits a typical 5-point rating scale, no rating values appear to be outside a reasonable range

# %% [markdown]
# ## Save Cleaned Dataset
#
# After checking column names, missing values, duplicate records, categorical values, and invalid numerical values, the dataset can be saved as a cleaned version

# %%
cleaned_file_path = "../Data/Cleaned/cleaned_dynamic_pricing.csv"
df.to_csv(cleaned_file_path, index=False)
print("Cleaned dataset saved")
# Out:
# Cleaned dataset saved

# %%
if os.path.exists(cleaned_file_path):
    print("File saved successfully.")
else:
    print("File was not saved.")
# Out:
# File saved successfully.
